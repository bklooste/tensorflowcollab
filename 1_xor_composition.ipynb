# %% [markdown]
# <a href="https://colab.research.google.com/github/bklooste/tensorflowcollab/blob/master/1_xor_composition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %%
import tensorflow as tf
import numpy as np

X = np.array(X)
y = np.array(y)

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(2, activation='relu'),
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=0)
_, acc = model.evaluate(X, y)
print('acc = ' + str(acc))
# Out:
# Train on 4 samples
# Epoch 1/100
# 4/4 [==============================] - 0s 57ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 5/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 6/100
# 4/4 [==============================] - 0s 952us/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 8/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 9/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 4.2028 - accuracy: 0.7500
# Epoch 10/100
# ...

# %%
import tensorflow as tf
import numpy as np

X = np.array(X)
y = np.array(y)

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(2, activation='relu'),
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=0)
_, acc = model.evaluate(X, y)
print('acc = ' + str(acc))
# Out:
# 4/4 [==============================] - 0s 16ms/sample - loss: 0.6322 - accuracy: 0.5000
# acc = 0.5

# %%
import tensorflow as tf
import numpy as np

X = np.array(X)
y = np.array(y)

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(2, activation='relu'),
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=0)
_, acc = model.evaluate(X, y)
print('acc = ' + str(acc))
# Out:
# 4/4 [==============================] - 0s 16ms/sample - loss: 0.6322 - accuracy: 0.5000
# acc = 0.5
